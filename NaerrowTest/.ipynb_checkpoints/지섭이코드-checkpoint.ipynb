# %%
import cv2
import tensorflow as tf
import numpy as np


from tensorflow.python.keras.models import load_model

config = tf.compat.v1.ConfigProto ()
config.gpu_options.per_process_gpu_memory_fraction = 0.4
session = tf.compat.v1 .Session (config = config)
samples_to_predict = []

# save model을 통해서 저장되는 것
# 1. 모델의 아키텍처(구조) -> 모델을 재구성할 수 있게해줌
# 2. 모델의 가중치
# 3. loss와 optimizer
# 4. optimizer의 상태와 resume할 위치(즉, 전에 끝난 위치)

# loss값은 적을수록 좋은 것,
def prepare(filepath):
    img_array = cv2.imread(filepath)
    new_array = cv2.resize(img_array,(122,187))
    return new_array.reshape(-1, 122, 187, 3)
########## 여서부터 CNN 시작 ############
# model = Sequential() # Sequential 모델은 각 레이어에 정확히 하나의 입력 텐서와 하나의 출력 텐서가 있는 일반 레이어 스택에 적합합니다
new_model = load_model('model/resnet50_model_6_19(64).h5', custom_objects={'tf': tf})
data="C:/Users/jaehee/.keras/datasets/snow_flo"
prediction = new_model.predict([prepare(data+'/weather/unnoisedn (1).png')])
#prediction = new_model.predict([prepare('C:/Users/jaehee/.keras/datasets/prediction_data/prediction/preprocessed/weather/n2.png')])

classes = np.argmax(prediction, axis = 1)
print(classes)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-26-9153949c5fd8> in <module>
#      24 ########## 여서부터 CNN 시작 ############
#      25 # model = Sequential() # Sequential 모델은 각 레이어에 정확히 하나의 입력 텐서와 하나의 출력 텐서가 있는 일반 레이어 스택에 적합합니다
# ---> 26 new_model = load_model('model/resnet50_model_6_19(64).h5', custom_objects={'tf': tf})
#      27 data="C:/Users/jaehee/.keras/datasets/snow_flo"
#      28 prediction = new_model.predict([prepare(data+'/weather/unnoisedn (1).png')])
#
# ~\anaconda3\envs\naerrow\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
# ...
